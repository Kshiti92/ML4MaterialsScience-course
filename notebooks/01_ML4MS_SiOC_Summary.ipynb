# %% [markdown]
# ## Machine Learning for Prediction of Thermal Conductivity in SiOC Glass Ceramics

# %% [markdown]
# #### About the System

# %% [markdown]
# ### Steps
#
# - Load Dataset
# - Visualize Dataset
# - Calculate Area Fraction and Volume Fraction of each phase
# - Check correlations between features and output(??)
# - Predict Thermal Conductivity by Linear Regression ML and NN (using volume fraction as input)
# - Predict thermal conductivity by CNN
